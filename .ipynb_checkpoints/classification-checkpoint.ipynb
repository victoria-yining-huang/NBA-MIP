# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.linear_model import LogisticRegression

from sklearn import metrics

import statsmodels.api as sm

# %%
df1 = pd.read_csv("player_stats_2018_2019.csv")

# %%
df1["season"] = 1819

# %%
df2 = pd.read_csv("player_stats_2017_2018.csv")

# %%
df2["season"] = 1718

# %%
df3 = pd.read_csv("player_stats_2016_2017.csv")

# %%
df3["season"] = 1617

# %%
df4 = pd.read_csv("player_stats_2015_2016.csv")

# %%
df4["season"] = 1516

# %%
df5 = pd.read_csv("player_stats_2014_2015.csv")

# %%
df5["season"] = 1415

# %%
df6 = pd.read_csv("player_stats_2013_2014.csv")

# %%
df6["season"] = 1314

# %%
df7 = pd.read_csv("player_stats_2012_2013.csv")

# %%
df7["season"] = 1213

# %%
df8 = pd.read_csv("player_stats_2011_2012.csv")

# %%
df8["season"] = 1112

# %%
df9 = pd.read_csv("player_stats_2010_2011.csv")

# %%
df9["season"] = 1011

# %%
df10 = pd.read_csv("player_stats_2009_2010.csv")

# %%
df10["season"] = '0910'

# %%
df11 = pd.read_csv("player_stats_2008_2009.csv")

# %%
df11["season"] = '0809'

# %%
df12 = pd.read_csv("player_stats_2007_2008.csv")

# %%
df12["season"] = '0708'

# %%
df13 = pd.read_csv("player_stats_2006_2007.csv")

# %%
df13["season"] = '0607'

# %%
df14 = pd.read_csv("player_stats_2005_2006.csv")

# %%
df14["season"] = '0506'

# %%
master = pd.DataFrame()

# %%
master.append([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14], ignore_index=True, sort=False)
# Out:
#        Rk                            Player Pos  Age   Tm   G  GS    MP    FG  \
# 0       1            ?lex Abrines\abrinal01  SG   25  OKC  31   2  19.0   1.8
# 1       2                Quincy Acy\acyqu01  PF   28  PHO  10   0  12.3   0.4
# 2       3            Jaylen Adams\adamsja01  PG   22  ATL  34   1  12.6   1.1
# 3       4            Steven Adams\adamsst01   C   25  OKC  80  80  33.4   6.0
# 4       5             Bam Adebayo\adebaba01   C   21  MIA  82  28  23.3   3.4
# 5       6                Deng Adel\adelde01  SF   21  CLE  19   3  10.2   0.6
# 6       7  DeVaughn Akoon-Purcell\akoonde01  SG   25  DEN   7   0   3.1   0.4
# 7       8       LaMarcus Aldridge\aldrila01   C   33  SAS  81  81  33.2   8.4
# 8       9            Rawle Alkins\alkinra01  SG   21  CHI  10   1  12.0   1.3
# 9      10           Grayson Allen\allengr01  SG   23  UTA  38   2  10.9   1.8
# 10     11           Jarrett Allen\allenja01   C   20  BRK  80  80  26.2   4.2
# 11     12            Kadeem Allen\allenka01  SG   26  NYK  19   1  21.9   3.4
# 12     13         Al-Farouq Aminu\aminual01  PF   28  POR  81  81  28.3   3.2
# 13     14         Justin Anderson\anderju01  SF   25  ATL  48   4   9.6   1.3
# 14     15           Kyle Anderson\anderky01  SF   25  MEM  43  40  29.8   3.5
# 15     17            Ike Anigbogu\anigbik01   C   20  IND   3   0   2.0   0.0
# 16     18   Giannis Antetokounmpo\antetgi01  PF   24  MIL  72  72  32.8  10.0
# 17     19    Kostas Antetokounmpo\antetko01  PF   21  DAL   2   0   5.5   0.0
# 18     20         Carmelo Anthony\anthoca01  PF   34  HOU  10   2  29.4   4.9
# 19     21              OG Anunoby\anunoog01  SF   21  TOR  67   6  20.2   2.7
# 20     22        Ryan Arcidiacono\arcidry01  PG   24  CHI  81  32  24.2   2.3
# 21     24           D.J. Augustin\augusdj01  PG   31  ORL  81  81  28.0   3.9
# 22     25           Deandre Ayton\aytonde01   C   20  PHO  71  70  30.7   7.2
# 23     26            Dwayne Bacon\bacondw01  SG   23  CHO  43  13  17.7   2.8
# 24     27           Marvin Bagley\baglema01  PF   19  SAC  62   4  25.3   5.7
# 25     29            Wade Baldwin\baldwwa01  PG   22  POR  16   0   5.9   0.6
# 26     30               Lonzo Ball\balllo01  PG   21  LAL  47  45  30.3   3.9
# 27     31                Mo Bamba\bambamo01   C   20  ORL  47   1  16.3   2.5
# 28     32              J.J. Barea\bareajo01  PG   34  DAL  38   0  19.8   4.2
# 29     34             Will Barton\bartowi01  SG   28  DEN  43  38  27.7   4.3
# ...   ...                               ...  ..  ...  ...  ..  ..   ...   ...
# 5792  424             Ben Wallace\wallabe01   C   31  DET  82  82  35.2   2.9
# 5793  425          Gerald Wallace\wallage01  SF   23  CHA  55  52  34.5   5.8
# 5794  426         Rasheed Wallace\wallara01  PF   31  DET  80  80  34.8   5.7
# 5795  427              Matt Walsh\walshma01  SG   23  MIA   2   0   1.5   0.5
# 5796  428             Luke Walton\waltolu01  SF   25  LAL  69   6  19.3   2.0
# 5797  429           Hakim Warrick\warriha01  PF   23  MEM  68   2  10.6   1.5
# 5798  431            Chris Webber\webbech01  PF   32  PHI  75  75  38.6   8.2
# 5799  432         Martell Webster\webstma02  SF   19  POR  61  18  17.5   2.3
# 5800  433             Bonzi Wells\wellsbo01  SG   29  SAC  52  41  32.4   5.5
# 5801  434             Ji?° Welsch\welscji01  SF   26  MIL  58   2  14.9   1.5
# 5802  435            David Wesley\wesleda01  SG   35  HOU  71  59  33.4   3.2
# 5803  436               David West\westda01  PF   25  NOK  74  74  34.1   7.2
# 5804  437             Delonte West\westde01  PG   22  BOS  71  71  34.1   4.7
# 5805  438           Robert Whaley\whalero01   C   23  UTA  23   0   9.2   1.0
# 5806  440          Damien Wilkins\wilkida02  SF   26  SEA  82  12  18.6   2.4
# 5807  443          Alvin Williams\willial02  PG   31  TOR   1   0  10.0   0.0
# 5808  444          Deron Williams\willide01  PG   21  UTA  80  47  28.8   4.2
# 5809  445           Eric Williams\willier01  SF   33  TOR  28  11  12.6   1.0
# 5810  446          Jason Williams\willija02  PG   30  MIA  59  56  31.8   4.5
# 5811  447            Lou Williams\willilo02  PG   19  PHI  30   0   4.8   0.8
# 5812  448         Marvin Williams\willima02  PF   19  ATL  79   7  24.7   3.0
# 5813  449             Mo Williams\willima01  PG   23  MIL  58  12  26.4   4.6
# 5814  450      Corliss Williamson\willico02  SF   32  SAC  37   0   9.8   1.2
# 5815  451             Loren Woods\woodslo01   C   27  TOR  27   4  12.0   1.0
# 5816  452            Qyntel Woods\woodsqy01  SF   24  NYK  49  16  20.7   2.6
# 5817  454          Antoine Wright\wrighan01  SG   21  NJN  39   0   9.5   0.7
# 5818  455           Bracey Wright\wrighbr02  SG   21  MIN   7   0  19.3   3.0
# 5819  456           Dorell Wright\wrighdo01  SF   20  MIA  20   2   6.6   1.0
# 5820  457         Lorenzen Wright\wrighlo02   C   30  MEM  78  58  21.7   2.5
# 5821  458       Derrick Zimmerman\zimmede01  PG   24  NJN   2   0  16.0   1.0
#
#        FGA  ...  DWS    WS  WS/48  OBPM  DBPM   BPM  VORP  MIP  season  Rk.1
# 0      5.1  ...  0.6   0.6  0.053  -2.4  -0.9  -3.4  -0.2    0    1819   NaN
# 1      1.8  ...  0.0  -0.1 -0.022  -5.7  -0.3  -5.9  -0.1    0    1819   NaN
# 2      3.2  ...  0.2   0.1  0.011  -3.1  -1.3  -4.4  -0.3    0    1819   NaN
# 3     10.1  ...  4.0   9.1  0.163   0.6   2.1   2.7   3.2    0    1819   NaN
# 4      5.9  ...  3.4   6.8  0.171  -0.6   3.6   3.0   2.4    0    1819   NaN
# 5      1.9  ...  0.0  -0.2 -0.054  -5.3  -2.0  -7.3  -0.3    0    1819   NaN
# 6      1.4  ...  0.0   0.0 -0.051  -4.4   0.8  -3.6   0.0    0    1819   NaN
# 7     16.3  ...  2.9   9.3  0.167   1.2   0.5   1.6   2.5    0    1819   NaN
# 8      3.9  ...  0.0  -0.1 -0.042  -4.1  -2.5  -6.5  -0.1    0    1819   NaN
# 9      4.7  ...  0.4   0.0  0.002  -3.7  -3.1  -6.8  -0.5    0    1819   NaN
# 10     7.1  ...  3.3   7.6  0.175  -0.7   3.2   2.5   2.4    0    1819   NaN
# 11     7.4  ...  0.2   1.0  0.111   0.5  -1.6  -1.1   0.1    0    1819   NaN
# 12     7.3  ...  2.8   5.8  0.121   0.1   0.8   0.9   1.7    0    1819   NaN
# 13     3.3  ...  0.4   0.4  0.043  -2.6  -0.7  -3.2  -0.1    0    1819   NaN
# 14     6.4  ...  1.8   2.7  0.100  -2.1   3.3   1.2   1.0    0    1819   NaN
# 15     1.0  ...  0.0  -0.1 -0.480 -22.5   8.5 -14.0   0.0    0    1819   NaN
# 16    17.3  ...  5.5  14.4  0.292   5.7   5.0  10.8   7.6    0    1819   NaN
# 17     1.5  ...  0.0  -0.1 -0.247 -15.9   2.7 -13.3   0.0    0    1819   NaN
# 18    12.1  ...  0.2   0.3  0.048  -3.1  -2.8  -5.9  -0.3    0    1819   NaN
# 19     6.0  ...  1.7   2.0  0.070  -1.3   0.1  -1.2   0.3    0    1819   NaN
# 20     5.2  ...  0.9   3.7  0.090  -0.1  -1.0  -1.0   0.5    0    1819   NaN
# 21     8.4  ...  1.9   6.9  0.146   1.7  -2.0  -0.3   1.0    0    1819   NaN
# 22    12.3  ...  1.7   5.8  0.128  -0.1   0.2   0.2   1.2    0    1819   NaN
# 23     6.0  ...  0.3   1.2  0.073  -1.2  -2.4  -3.5  -0.3    0    1819   NaN
# 24    11.4  ...  1.6   3.6  0.110  -1.2  -0.7  -1.8   0.1    0    1819   NaN
# 25     2.1  ...  0.1  -0.3 -0.153  -9.3  -1.4 -10.7  -0.2    0    1819   NaN
# 26     9.7  ...  1.7   1.6  0.052  -0.9   1.5   0.5   0.9    0    1819   NaN
# 27     5.2  ...  1.4   1.7  0.106  -3.3   3.1  -0.2   0.4    0    1819   NaN
# 28    10.1  ...  0.6   1.0  0.064   1.1  -2.2  -1.1   0.2    0    1819   NaN
# 29    10.7  ...  1.1   1.2  0.049  -1.8  -0.5  -2.3  -0.1    0    1819   NaN
# ...    ...  ...  ...   ...    ...   ...   ...   ...   ...  ...     ...   ...
# 5792   5.7  ...  6.9  10.1  0.168  -0.6   6.4   5.8   5.7    0    0506   NaN
# 5793  10.7  ...  3.4   6.4  0.163   1.1   4.7   5.8   3.7    1    0506   NaN
# 5794  13.3  ...  4.9   8.9  0.154   1.5   2.0   3.5   3.9    0    0506   NaN
# 5795   0.5  ...  0.0   0.0 -0.642 -17.7  -8.2 -25.9   0.0    0    0506   NaN
# 5796   4.8  ...  1.3   2.0  0.071  -1.8   0.4  -1.3   0.2    0    0506   NaN
# 5797   3.4  ...  1.1   0.8  0.053  -5.3  -0.3  -5.5  -0.6    0    0506   NaN
# 5798  19.0  ...  3.3   4.4  0.074  -0.9   0.5  -0.4   1.2    0    0506   NaN
# 5799   5.7  ...  0.1   0.9  0.039  -0.2  -3.0  -3.2  -0.3    0    0506   NaN
# 5800  11.8  ...  2.7   3.4  0.096  -0.4   2.2   1.8   1.6    0    0506   NaN
# 5801   3.8  ...  0.7   0.8  0.043  -2.9  -0.3  -3.2  -0.3    0    0506   NaN
# 5802   7.9  ...  2.2   3.6  0.072  -0.6  -0.1  -0.7   0.8    0    0506   NaN
# 5803  14.0  ...  2.6   7.4  0.141   0.9   0.1   1.0   1.9    1    0506   NaN
# 5804   9.6  ...  2.1   5.7  0.114   1.6   0.4   1.9   2.4    0    0506   NaN
# 5805   2.5  ...  0.3   0.0  0.004  -4.7   1.3  -3.5  -0.1    0    0506   NaN
# 5806   5.3  ...  0.1   1.7  0.054  -0.2  -1.3  -1.5   0.2    0    0506   NaN
# 5807   3.0  ...  0.0  -0.1 -0.278 -14.9  -8.5 -23.4  -0.1    0    0506   NaN
# 5808  10.1  ...  1.3   2.8  0.059   0.1  -2.4  -2.3  -0.2    0    0506   NaN
# 5809   2.7  ...  0.0   0.1  0.011  -3.4  -1.9  -5.3  -0.3    0    0506   NaN
# 5810  10.3  ...  1.6   4.8  0.124   2.1  -1.6   0.4   1.2    0    0506   NaN
# 5811   1.7  ...  0.1  -0.1 -0.036  -5.3  -2.8  -8.1  -0.2    0    0506   NaN
# 5812   6.7  ...  0.7   2.8  0.069  -1.7  -1.9  -3.7  -0.8    0    0506   NaN
# 5813  10.8  ...  1.0   2.5  0.079   1.2  -1.7  -0.6   0.6    0    0506   NaN
# 5814   2.8  ...  0.4   0.2  0.021  -5.6  -1.5  -7.1  -0.5    0    0506   NaN
# 5815   2.2  ...  0.3   0.4  0.064  -3.9   1.0  -2.9  -0.1    0    0506   NaN
# 5816   5.2  ...  0.6   1.3  0.061  -0.7   0.0  -0.7   0.3    0    0506   NaN
# 5817   2.1  ...  0.3  -0.5 -0.062  -8.2  -0.8  -9.0  -0.7    0    0506   NaN
# 5818   7.3  ...  0.1   0.2  0.054  -2.2  -3.9  -6.1  -0.1    0    0506   NaN
# 5819   2.2  ...  0.2   0.2  0.064  -4.8  -0.8  -5.6  -0.1    0    0506   NaN
# 5820   5.2  ...  3.0   3.7  0.106  -3.0   1.6  -1.3   0.3    0    0506   NaN
# 5821   1.5  ...  0.0   0.0  0.004  -7.1  -2.6  -9.7  -0.1    0    0506   NaN
#
# [5822 rows x 53 columns]

# %%
features = pd.DataFrame()

# %% [markdown]
# master["Player"]

# %%
features = master[['Player','MP','PTS','TRB','AST','STL','BLK','FG%','3P%','FT%','WS']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-7fe496f81a0b> in <module>
# ----> 1 features = master[['Player','MP','PTS','TRB','AST','STL','BLK','FG%','3P%','FT%','WS']]
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1244                 raise KeyError(
#    1245                     u"None of [{key}] are in the [{axis}]".format(
# -> 1246                         key=key, axis=self.obj._get_axis_name(axis)))
#    1247
#    1248             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['Player', 'MP', 'PTS', 'TRB', 'AST', 'STL', 'BLK', 'FG%', '3P%', 'FT%',\n       'WS'],\n      dtype='object')] are in the [columns]"

# %%
master["Player"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Player'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-ea57d4fce52e> in <module>
# ----> 1 master["Player"]
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Player'
